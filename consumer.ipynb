# %% [markdown]
# ##### **Load Library**

# %%
import json
import pandas

from kafka import KafkaConsumer
from sqlalchemy import create_engine

# %% [markdown]
# ##### **Run Process**

# %%
if __name__ == "__main__":
    engine = create_engine('postgresql://de17:de17!#@34.126.160.212:5432/project6')
    consumer = KafkaConsumer("erik", bootstrap_servers='34.126.160.212')
    print("starting the consumer")
    for msg in consumer:
        print(f"Records = {json.loads(msg.value)}")

        data = json.loads(msg.value)
        df = pandas.DataFrame(data, index=[0])
        df.to_sql('user_activity_erik', engine, if_exists='append', index=False)
# Out:
# starting the consumer
# Records = {'Id': 18, 'logTimestamp': 1652807231000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 21, 'logTimestamp': 1653027199000, 'devideId': 'Windows Phone', 'logActivity': 'Logout'}
# Records = {'Id': 84, 'logTimestamp': 1651883801000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 34, 'logTimestamp': 1652526498000, 'devideId': 'OS', 'logActivity': 'Search'}
# Records = {'Id': 67, 'logTimestamp': 1651758836000, 'devideId': 'Windows Phone', 'logActivity': 'Payment'}
# Records = {'Id': 105, 'logTimestamp': 1652522205000, 'devideId': 'Windows Phone', 'logActivity': 'Menu'}
# Records = {'Id': 33, 'logTimestamp': 1651450516000, 'devideId': 'OS', 'logActivity': 'Search'}
# Records = {'Id': 30, 'logTimestamp': 1653174650000, 'devideId': 'Windows Phone', 'logActivity': 'Menu'}
# Records = {'Id': 97, 'logTimestamp': 1653630515000, 'devideId': 'OS', 'logActivity': 'Search'}
# Records = {'Id': 80, 'logTimestamp': 1653186017000, 'devideId': 'Windows Phone', 'logActivity': 'Payment'}
# Records = {'Id': 59, 'logTimestamp': 1651779990000, 'devideId': 'OS', 'logActivity': 'Menu'}
# Records = {'Id': 31, 'logTimestamp': 1651251037000, 'devideId': 'Windows Phone', 'logActivity': 'Login'}
# Records = {'Id': 66, 'logTimestamp': 1651193692000, 'devideId': 'Windows Phone', 'logActivity': 'Logout'}
# Records = {'Id': 37, 'logTimestamp': 1651321100000, 'devideId': 'Windows Phone', 'logActivity': 'Login'}
# Records = {'Id': 59, 'logTimestamp': 1652866677000, 'devideId': 'Windows Phone', 'logActivity': 'Menu'}
# Records = {'Id': 22, 'logTimestamp': 1652690204000, 'devideId': 'Windows Phone', 'logActivity': 'Search'}
# Records = {'Id': 0, 'logTimestamp': 1652491980000, 'devideId': 'OS', 'logActivity': 'Menu'}
# Records = {'Id': 2, 'logTimestamp': 1653444742000, 'devideId': 'OS', 'logActivity': 'Menu'}
# Records = {'Id': 91, 'logTimestamp': 1653164569000, 'devideId': 'Windows Phone', 'logActivity': 'Search'}
# Records = {'Id': 23, 'logTimestamp': 1653060944000, 'devideId': 'OS', 'logActivity': 'Login'}
# Records = {'Id': 41, 'logTimestamp': 1652709800000, 'devideId': 'Windows Phone', 'logActivity': 'Menu'}
# Records = {'Id': 82, 'logTimestamp': 1651456834000, 'devideId': 'OS', 'logActivity': 'Logout'}
# Records = {'Id': 7, 'logTimestamp': 1651984114000, 'devideId': 'OS', 'logActivity': 'Logout'}
# Records = {'Id': 2, 'logTimestamp': 1651399210000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 95, 'logTimestamp': 1652773596000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 63, 'logTimestamp': 1651631348000, 'devideId': 'Windows Phone', 'logActivity': 'Search'}
# Records = {'Id': 104, 'logTimestamp': 1651709191000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 92, 'logTimestamp': 1653627938000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 52, 'logTimestamp': 1652112340000, 'devideId': 'OS', 'logActivity': 'Login'}
# Records = {'Id': 13, 'logTimestamp': 1651809091000, 'devideId': 'Windows Phone', 'logActivity': 'Search'}
# Records = {'Id': 1, 'logTimestamp': 1652570195000, 'devideId': 'Android', 'logActivity': 'Search'}
# Records = {'Id': 39, 'logTimestamp': 1651222439000, 'devideId': 'Android', 'logActivity': 'Login'}
# Records = {'Id': 15, 'logTimestamp': 1651749990000, 'devideId': 'OS', 'logActivity': 'Login'}
# Records = {'Id': 25, 'logTimestamp': 1652411554000, 'devideId': 'Windows Phone', 'logActivity': 'Logout'}
# Records = {'Id': 47, 'logTimestamp': 1652115970000, 'devideId': 'Windows Phone', 'logActivity': 'Logout'}
# Records = {'Id': 81, 'logTimestamp': 1652712157000, 'devideId': 'OS', 'logActivity': 'Search'}
# Records = {'Id': 35, 'logTimestamp': 1652157152000, 'devideId': 'OS', 'logActivity': 'Search'}
# Records = {'Id': 96, 'logTimestamp': 1652751067000, 'devideId': 'OS', 'logActivity': 'Payment'}
# Records = {'Id': 30, 'logTimestamp': 1652911413000, 'devideId': 'OS', 'logActivity': 'Logout'}
# Records = {'Id': 19, 'logTimestamp': 1653401633000, 'devideId': 'Android', 'logActivity': 'Payment'}
# Records = {'Id': 23, 'logTimestamp': 1651606486000, 'devideId': 'OS', 'logActivity': 'Logout'}
# Records = {'Id': 6, 'logTimestamp': 1651998049000, 'devideId': 'Android', 'logActivity': 'Login'}
# Records = {'Id': 30, 'logTimestamp': 1652018908000, 'devideId': 'Windows Phone', 'logActivity': 'Menu'}
# Records = {'Id': 49, 'logTimestamp': 1653409583000, 'devideId': 'OS', 'logActivity': 'Logout'}
# Records = {'Id': 6, 'logTimestamp': 1653050319000, 'devideId': 'Android', 'logActivity': 'Logout'}
# Records = {'Id': 20, 'logTimestamp': 1652828232000, 'devideId': 'Windows Phone', 'logActivity': 'Payment'}
# Records = {'Id': 2, 'logTimestamp': 1653271291000, 'devideId': 'Android', 'logActivity': 'Login'}
# Records = {'Id': 79, 'logTimestamp': 1653155642000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 37, 'logTimestamp': 1652214751000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 92, 'logTimestamp': 1652148921000, 'devideId': 'OS', 'logActivity': 'Menu'}
# Records = {'Id': 11, 'logTimestamp': 1651723873000, 'devideId': 'OS', 'logActivity': 'Login'}
# Records = {'Id': 103, 'logTimestamp': 1652703250000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 95, 'logTimestamp': 1653197357000, 'devideId': 'Android', 'logActivity': 'Search'}
# Records = {'Id': 103, 'logTimestamp': 1651867019000, 'devideId': 'OS', 'logActivity': 'Menu'}
# Records = {'Id': 82, 'logTimestamp': 1652939860000, 'devideId': 'Windows Phone', 'logActivity': 'Login'}
# Records = {'Id': 36, 'logTimestamp': 1651594087000, 'devideId': 'OS', 'logActivity': 'Search'}
# Records = {'Id': 17, 'logTimestamp': 1652836375000, 'devideId': 'Windows Phone', 'logActivity': 'Menu'}
# Records = {'Id': 84, 'logTimestamp': 1653057309000, 'devideId': 'Windows Phone', 'logActivity': 'Payment'}
# Records = {'Id': 24, 'logTimestamp': 1652617924000, 'devideId': 'OS', 'logActivity': 'Login'}
# Records = {'Id': 48, 'logTimestamp': 1651514122000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 106, 'logTimestamp': 1651967126000, 'devideId': 'Windows Phone', 'logActivity': 'Menu'}
# Records = {'Id': 62, 'logTimestamp': 1652114341000, 'devideId': 'Android', 'logActivity': 'Payment'}
# Records = {'Id': 28, 'logTimestamp': 1653241493000, 'devideId': 'Windows Phone', 'logActivity': 'Logout'}
# Records = {'Id': 73, 'logTimestamp': 1652689978000, 'devideId': 'Android', 'logActivity': 'Logout'}
# Records = {'Id': 10, 'logTimestamp': 1651476852000, 'devideId': 'OS', 'logActivity': 'Payment'}
# Records = {'Id': 17, 'logTimestamp': 1653074406000, 'devideId': 'Android', 'logActivity': 'Logout'}
# Records = {'Id': 63, 'logTimestamp': 1651413907000, 'devideId': 'Windows Phone', 'logActivity': 'Logout'}
# Records = {'Id': 69, 'logTimestamp': 1651489547000, 'devideId': 'Windows Phone', 'logActivity': 'Search'}
# Records = {'Id': 42, 'logTimestamp': 1653083570000, 'devideId': 'Android', 'logActivity': 'Login'}
# Records = {'Id': 2, 'logTimestamp': 1653399659000, 'devideId': 'OS', 'logActivity': 'Payment'}
# Records = {'Id': 8, 'logTimestamp': 1653082271000, 'devideId': 'Android', 'logActivity': 'Payment'}
# Records = {'Id': 45, 'logTimestamp': 1651540332000, 'devideId': 'Windows Phone', 'logActivity': 'Payment'}
# Records = {'Id': 78, 'logTimestamp': 1653019520000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 85, 'logTimestamp': 1652050309000, 'devideId': 'Windows Phone', 'logActivity': 'Search'}
# Records = {'Id': 65, 'logTimestamp': 1652704498000, 'devideId': 'Windows Phone', 'logActivity': 'Login'}
# Records = {'Id': 62, 'logTimestamp': 1652249523000, 'devideId': 'OS', 'logActivity': 'Payment'}
# Records = {'Id': 76, 'logTimestamp': 1652856071000, 'devideId': 'OS', 'logActivity': 'Login'}
# Records = {'Id': 40, 'logTimestamp': 1653309603000, 'devideId': 'Android', 'logActivity': 'Logout'}
# Records = {'Id': 25, 'logTimestamp': 1652764980000, 'devideId': 'OS', 'logActivity': 'Menu'}
# Records = {'Id': 98, 'logTimestamp': 1653282969000, 'devideId': 'OS', 'logActivity': 'Payment'}
# Records = {'Id': 63, 'logTimestamp': 1652903428000, 'devideId': 'OS', 'logActivity': 'Menu'}
# Records = {'Id': 78, 'logTimestamp': 1651976194000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 14, 'logTimestamp': 1652144610000, 'devideId': 'OS', 'logActivity': 'Payment'}
# Records = {'Id': 57, 'logTimestamp': 1653311660000, 'devideId': 'OS', 'logActivity': 'Logout'}
# Records = {'Id': 13, 'logTimestamp': 1652983656000, 'devideId': 'Android', 'logActivity': 'Search'}
# Records = {'Id': 18, 'logTimestamp': 1651155600000, 'devideId': 'Android', 'logActivity': 'Search'}
# Records = {'Id': 46, 'logTimestamp': 1651769816000, 'devideId': 'Windows Phone', 'logActivity': 'Menu'}
# Records = {'Id': 14, 'logTimestamp': 1651131450000, 'devideId': 'OS', 'logActivity': 'Menu'}
# Records = {'Id': 22, 'logTimestamp': 1652555299000, 'devideId': 'Android', 'logActivity': 'Logout'}
# Records = {'Id': 64, 'logTimestamp': 1652577931000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 1, 'logTimestamp': 1653486781000, 'devideId': 'Windows Phone', 'logActivity': 'Search'}
# Records = {'Id': 88, 'logTimestamp': 1653599376000, 'devideId': 'Windows Phone', 'logActivity': 'Menu'}
# Records = {'Id': 63, 'logTimestamp': 1652605993000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 9, 'logTimestamp': 1651929302000, 'devideId': 'OS', 'logActivity': 'Login'}
# Records = {'Id': 35, 'logTimestamp': 1651631517000, 'devideId': 'Windows Phone', 'logActivity': 'Search'}
# Records = {'Id': 86, 'logTimestamp': 1651559361000, 'devideId': 'OS', 'logActivity': 'Search'}
# Records = {'Id': 98, 'logTimestamp': 1652194765000, 'devideId': 'OS', 'logActivity': 'Menu'}
# Records = {'Id': 41, 'logTimestamp': 1651125772000, 'devideId': 'OS', 'logActivity': 'Payment'}
# Records = {'Id': 73, 'logTimestamp': 1651244227000, 'devideId': 'OS', 'logActivity': 'Logout'}
# Records = {'Id': 63, 'logTimestamp': 1652647104000, 'devideId': 'Windows Phone', 'logActivity': 'Menu'}
# Records = {'Id': 103, 'logTimestamp': 1651901209000, 'devideId': 'OS', 'logActivity': 'Logout'}
# Records = {'Id': 101, 'logTimestamp': 1651796634000, 'devideId': 'OS', 'logActivity': 'Search'}
# Records = {'Id': 48, 'logTimestamp': 1651098965000, 'devideId': 'Windows Phone', 'logActivity': 'Menu'}
# Records = {'Id': 43, 'logTimestamp': 1651568646000, 'devideId': 'OS', 'logActivity': 'Logout'}
# Records = {'Id': 31, 'logTimestamp': 1653183580000, 'devideId': 'OS', 'logActivity': 'Logout'}
# Records = {'Id': 19, 'logTimestamp': 1651231605000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 59, 'logTimestamp': 1653451785000, 'devideId': 'Android', 'logActivity': 'Search'}
# Records = {'Id': 86, 'logTimestamp': 1652218595000, 'devideId': 'Windows Phone', 'logActivity': 'Login'}
# Records = {'Id': 96, 'logTimestamp': 1652112830000, 'devideId': 'Windows Phone', 'logActivity': 'Logout'}
# Records = {'Id': 99, 'logTimestamp': 1653280783000, 'devideId': 'Windows Phone', 'logActivity': 'Menu'}
# Records = {'Id': 17, 'logTimestamp': 1652562751000, 'devideId': 'Android', 'logActivity': 'Payment'}
# Records = {'Id': 81, 'logTimestamp': 1652075966000, 'devideId': 'OS', 'logActivity': 'Menu'}
# Records = {'Id': 70, 'logTimestamp': 1653174879000, 'devideId': 'OS', 'logActivity': 'Logout'}
# Records = {'Id': 69, 'logTimestamp': 1651304324000, 'devideId': 'OS', 'logActivity': 'Menu'}
# Records = {'Id': 18, 'logTimestamp': 1651491399000, 'devideId': 'Android', 'logActivity': 'Logout'}
# Records = {'Id': 86, 'logTimestamp': 1653169876000, 'devideId': 'OS', 'logActivity': 'Payment'}
# Records = {'Id': 9, 'logTimestamp': 1651829414000, 'devideId': 'Windows Phone', 'logActivity': 'Logout'}
# Records = {'Id': 37, 'logTimestamp': 1652733810000, 'devideId': 'Android', 'logActivity': 'Payment'}
# Records = {'Id': 56, 'logTimestamp': 1651545849000, 'devideId': 'Android', 'logActivity': 'Logout'}
# Records = {'Id': 86, 'logTimestamp': 1651570012000, 'devideId': 'Android', 'logActivity': 'Login'}
# Records = {'Id': 91, 'logTimestamp': 1651419769000, 'devideId': 'Windows Phone', 'logActivity': 'Search'}
# Records = {'Id': 15, 'logTimestamp': 1652771890000, 'devideId': 'Windows Phone', 'logActivity': 'Logout'}
# Records = {'Id': 29, 'logTimestamp': 1652487274000, 'devideId': 'OS', 'logActivity': 'Search'}
# Records = {'Id': 64, 'logTimestamp': 1652862768000, 'devideId': 'OS', 'logActivity': 'Payment'}
# Records = {'Id': 71, 'logTimestamp': 1652152801000, 'devideId': 'Windows Phone', 'logActivity': 'Logout'}
# Records = {'Id': 101, 'logTimestamp': 1652216433000, 'devideId': 'OS', 'logActivity': 'Logout'}
# Records = {'Id': 37, 'logTimestamp': 1653541708000, 'devideId': 'OS', 'logActivity': 'Payment'}
# Records = {'Id': 18, 'logTimestamp': 1652936638000, 'devideId': 'OS', 'logActivity': 'Payment'}
# Records = {'Id': 3, 'logTimestamp': 1652859337000, 'devideId': 'OS', 'logActivity': 'Menu'}
# Records = {'Id': 27, 'logTimestamp': 1651788472000, 'devideId': 'Windows Phone', 'logActivity': 'Payment'}
# Records = {'Id': 52, 'logTimestamp': 1651743196000, 'devideId': 'Windows Phone', 'logActivity': 'Payment'}
# Records = {'Id': 70, 'logTimestamp': 1653607151000, 'devideId': 'Android', 'logActivity': 'Logout'}
# Records = {'Id': 48, 'logTimestamp': 1652752519000, 'devideId': 'OS', 'logActivity': 'Logout'}
# Records = {'Id': 0, 'logTimestamp': 1651962330000, 'devideId': 'Windows Phone', 'logActivity': 'Payment'}
# Records = {'Id': 2, 'logTimestamp': 1652342189000, 'devideId': 'Android', 'logActivity': 'Payment'}
# Records = {'Id': 40, 'logTimestamp': 1651056776000, 'devideId': 'Android', 'logActivity': 'Payment'}
# Records = {'Id': 2, 'logTimestamp': 1652322475000, 'devideId': 'Android', 'logActivity': 'Logout'}
# Records = {'Id': 55, 'logTimestamp': 1652855843000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 3, 'logTimestamp': 1652560128000, 'devideId': 'Android', 'logActivity': 'Login'}
# Records = {'Id': 79, 'logTimestamp': 1652492084000, 'devideId': 'Android', 'logActivity': 'Payment'}
# Records = {'Id': 72, 'logTimestamp': 1651255827000, 'devideId': 'Windows Phone', 'logActivity': 'Menu'}
# Records = {'Id': 76, 'logTimestamp': 1652360805000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 94, 'logTimestamp': 1651199900000, 'devideId': 'OS', 'logActivity': 'Logout'}
# Records = {'Id': 49, 'logTimestamp': 1653407955000, 'devideId': 'Android', 'logActivity': 'Login'}
# Records = {'Id': 95, 'logTimestamp': 1653418745000, 'devideId': 'Windows Phone', 'logActivity': 'Search'}
# Records = {'Id': 0, 'logTimestamp': 1653297348000, 'devideId': 'OS', 'logActivity': 'Menu'}
# Records = {'Id': 33, 'logTimestamp': 1653271441000, 'devideId': 'Windows Phone', 'logActivity': 'Payment'}
# Records = {'Id': 42, 'logTimestamp': 1651350604000, 'devideId': 'Windows Phone', 'logActivity': 'Logout'}
# Records = {'Id': 73, 'logTimestamp': 1652362105000, 'devideId': 'Android', 'logActivity': 'Login'}
# Records = {'Id': 9, 'logTimestamp': 1651373673000, 'devideId': 'Windows Phone', 'logActivity': 'Login'}
# Records = {'Id': 104, 'logTimestamp': 1651170540000, 'devideId': 'Windows Phone', 'logActivity': 'Login'}
# Records = {'Id': 96, 'logTimestamp': 1652978728000, 'devideId': 'OS', 'logActivity': 'Payment'}
# Records = {'Id': 104, 'logTimestamp': 1651945680000, 'devideId': 'Android', 'logActivity': 'Login'}
# Records = {'Id': 29, 'logTimestamp': 1653263990000, 'devideId': 'Windows Phone', 'logActivity': 'Logout'}
# Records = {'Id': 93, 'logTimestamp': 1653066754000, 'devideId': 'Android', 'logActivity': 'Logout'}
# Records = {'Id': 78, 'logTimestamp': 1652062335000, 'devideId': 'OS', 'logActivity': 'Search'}
# Records = {'Id': 11, 'logTimestamp': 1651734862000, 'devideId': 'Windows Phone', 'logActivity': 'Search'}
# Records = {'Id': 40, 'logTimestamp': 1652293445000, 'devideId': 'Windows Phone', 'logActivity': 'Search'}
# Records = {'Id': 90, 'logTimestamp': 1653474514000, 'devideId': 'OS', 'logActivity': 'Search'}
# Records = {'Id': 104, 'logTimestamp': 1653405361000, 'devideId': 'Android', 'logActivity': 'Login'}
# Records = {'Id': 39, 'logTimestamp': 1653091276000, 'devideId': 'Windows Phone', 'logActivity': 'Payment'}
# Records = {'Id': 81, 'logTimestamp': 1653199212000, 'devideId': 'OS', 'logActivity': 'Logout'}
# Records = {'Id': 53, 'logTimestamp': 1651998816000, 'devideId': 'OS', 'logActivity': 'Login'}
# Records = {'Id': 89, 'logTimestamp': 1652442431000, 'devideId': 'OS', 'logActivity': 'Search'}
# Records = {'Id': 106, 'logTimestamp': 1651190972000, 'devideId': 'OS', 'logActivity': 'Logout'}
# Records = {'Id': 100, 'logTimestamp': 1652032614000, 'devideId': 'OS', 'logActivity': 'Logout'}
# Records = {'Id': 98, 'logTimestamp': 1651246176000, 'devideId': 'OS', 'logActivity': 'Login'}
# Records = {'Id': 97, 'logTimestamp': 1653369272000, 'devideId': 'OS', 'logActivity': 'Login'}
# Records = {'Id': 6, 'logTimestamp': 1651439925000, 'devideId': 'Android', 'logActivity': 'Payment'}
# Records = {'Id': 4, 'logTimestamp': 1651783696000, 'devideId': 'Windows Phone', 'logActivity': 'Logout'}
# Records = {'Id': 79, 'logTimestamp': 1651490067000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 101, 'logTimestamp': 1651528187000, 'devideId': 'Windows Phone', 'logActivity': 'Menu'}
# Records = {'Id': 82, 'logTimestamp': 1651277971000, 'devideId': 'OS', 'logActivity': 'Payment'}
# Records = {'Id': 45, 'logTimestamp': 1651613573000, 'devideId': 'Windows Phone', 'logActivity': 'Logout'}
# Records = {'Id': 13, 'logTimestamp': 1651366729000, 'devideId': 'Windows Phone', 'logActivity': 'Menu'}
# Records = {'Id': 21, 'logTimestamp': 1652276230000, 'devideId': 'OS', 'logActivity': 'Search'}
# Records = {'Id': 5, 'logTimestamp': 1651074956000, 'devideId': 'Windows Phone', 'logActivity': 'Payment'}
# Records = {'Id': 21, 'logTimestamp': 1651958034000, 'devideId': 'Windows Phone', 'logActivity': 'Login'}
# Records = {'Id': 44, 'logTimestamp': 1653380576000, 'devideId': 'Windows Phone', 'logActivity': 'Login'}
# Records = {'Id': 97, 'logTimestamp': 1653223912000, 'devideId': 'Windows Phone', 'logActivity': 'Menu'}
# Records = {'Id': 91, 'logTimestamp': 1651873860000, 'devideId': 'Windows Phone', 'logActivity': 'Search'}
# Records = {'Id': 20, 'logTimestamp': 1652784903000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 8, 'logTimestamp': 1652430615000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 5, 'logTimestamp': 1651302785000, 'devideId': 'Windows Phone', 'logActivity': 'Payment'}
# Records = {'Id': 67, 'logTimestamp': 1653146469000, 'devideId': 'Android', 'logActivity': 'Login'}
# Records = {'Id': 67, 'logTimestamp': 1652148951000, 'devideId': 'Windows Phone', 'logActivity': 'Menu'}
# Records = {'Id': 62, 'logTimestamp': 1652298894000, 'devideId': 'OS', 'logActivity': 'Login'}
# Records = {'Id': 74, 'logTimestamp': 1653582325000, 'devideId': 'Android', 'logActivity': 'Search'}
# Records = {'Id': 6, 'logTimestamp': 1652540652000, 'devideId': 'Windows Phone', 'logActivity': 'Menu'}
# Records = {'Id': 1, 'logTimestamp': 1652320570000, 'devideId': 'OS', 'logActivity': 'Menu'}
# Records = {'Id': 34, 'logTimestamp': 1651525067000, 'devideId': 'Windows Phone', 'logActivity': 'Payment'}
# Records = {'Id': 53, 'logTimestamp': 1652960837000, 'devideId': 'OS', 'logActivity': 'Menu'}
# Records = {'Id': 23, 'logTimestamp': 1652090348000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 74, 'logTimestamp': 1651960567000, 'devideId': 'Android', 'logActivity': 'Logout'}
# Records = {'Id': 12, 'logTimestamp': 1651471768000, 'devideId': 'OS', 'logActivity': 'Menu'}
# Records = {'Id': 21, 'logTimestamp': 1652686756000, 'devideId': 'OS', 'logActivity': 'Search'}
# Records = {'Id': 18, 'logTimestamp': 1652082066000, 'devideId': 'OS', 'logActivity': 'Payment'}
# Records = {'Id': 106, 'logTimestamp': 1651102385000, 'devideId': 'Windows Phone', 'logActivity': 'Search'}
# Records = {'Id': 9, 'logTimestamp': 1652616883000, 'devideId': 'Windows Phone', 'logActivity': 'Search'}
# Records = {'Id': 95, 'logTimestamp': 1652933111000, 'devideId': 'Windows Phone', 'logActivity': 'Payment'}
# Records = {'Id': 45, 'logTimestamp': 1653464203000, 'devideId': 'Android', 'logActivity': 'Login'}
# Records = {'Id': 41, 'logTimestamp': 1652533885000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 35, 'logTimestamp': 1653240563000, 'devideId': 'Android', 'logActivity': 'Search'}
# Records = {'Id': 36, 'logTimestamp': 1651612437000, 'devideId': 'Android', 'logActivity': 'Payment'}
# Records = {'Id': 86, 'logTimestamp': 1652723838000, 'devideId': 'Windows Phone', 'logActivity': 'Login'}
# Records = {'Id': 44, 'logTimestamp': 1652539140000, 'devideId': 'OS', 'logActivity': 'Login'}
# Records = {'Id': 35, 'logTimestamp': 1653628292000, 'devideId': 'Windows Phone', 'logActivity': 'Login'}
# Records = {'Id': 88, 'logTimestamp': 1653241750000, 'devideId': 'Windows Phone', 'logActivity': 'Payment'}
# Records = {'Id': 35, 'logTimestamp': 1652217068000, 'devideId': 'Android', 'logActivity': 'Search'}
# Records = {'Id': 96, 'logTimestamp': 1652411735000, 'devideId': 'Windows Phone', 'logActivity': 'Logout'}
# Records = {'Id': 0, 'logTimestamp': 1652179682000, 'devideId': 'OS', 'logActivity': 'Menu'}
# Records = {'Id': 33, 'logTimestamp': 1651873727000, 'devideId': 'Android', 'logActivity': 'Login'}
# Records = {'Id': 19, 'logTimestamp': 1651495244000, 'devideId': 'Android', 'logActivity': 'Menu'}
# Records = {'Id': 80, 'logTimestamp': 1651534570000, 'devideId': 'Windows Phone', 'logActivity': 'Logout'}
# Records = {'Id': 9, 'logTimestamp': 1653023782000, 'devideId': 'Android', 'logActivity': 'Logout'}
# Records = {'Id': 47, 'logTimestamp': 1651328337000, 'devideId': 'Windows Phone', 'logActivity': 'Login'}
# Records = {'Id': 83, 'logTimestamp': 1651481423000, 'devideId': 'Windows Phone', 'logActivity': 'Menu'}
# Records = {'Id': 7, 'logTimestamp': 1652103156000, 'devideId': 'Windows Phone', 'logActivity': 'Logout'}
# Records = {'Id': 29, 'logTimestamp': 1652476290000, 'devideId': 'OS', 'logActivity': 'Search'}
# Records = {'Id': 103, 'logTimestamp': 1652218546000, 'devideId': 'OS', 'logActivity': 'Payment'}
# Records = {'Id': 62, 'logTimestamp': 1653585404000, 'devideId': 'Android', 'logActivity': 'Logout'}
# Records = {'Id': 52, 'logTimestamp': 1653479520000, 'devideId': 'Android', 'logActivity': 'Login'}
# Records = {'Id': 45, 'logTimestamp': 1653122154000, 'devideId': 'Android', 'logActivity': 'Search'}
# Records = {'Id': 22, 'logTimestamp': 1653460450000, 'devideId': 'OS', 'logActivity': 'Search'}
# Records = {'Id': 77, 'logTimestamp': 1653468264000, 'devideId': 'OS', 'logActivity': 'Logout'}
# Records = {'Id': 92, 'logTimestamp': 1651204588000, 'devideId': 'OS', 'logActivity': 'Menu'}
# Records = {'Id': 103, 'logTimestamp': 1651417214000, 'devideId': 'Windows Phone', 'logActivity': 'Payment'}
# Records = {'Id': 106, 'logTimestamp': 1651337217000, 'devideId': 'Windows Phone', 'logActivity': 'Menu'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 5
#       3 consumer = KafkaConsumer("erik", bootstrap_servers='34.126.160.212')
#       4 print("starting the consumer")
# ----> 5 for msg in consumer:
#       6     print(f"Records = {json.loads(msg.value)}")
#       8     data = json.loads(msg.value)
#
# File ~/venv/lib/python3.8/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~/venv/lib/python3.8/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~/venv/lib/python3.8/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~/venv/lib/python3.8/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~/venv/lib/python3.8/site-packages/kafka/consumer/group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~/venv/lib/python3.8/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~/venv/lib/python3.8/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File /usr/lib/python3.8/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:
